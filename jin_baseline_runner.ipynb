# %% [markdown]
# # emg2qwerty Baseline Runner
#
#
# This notebook runs:
# `python -c "<patch torch.load; runpy.run_module('emg2qwerty.train', run_name='__main__')>" user=... dataset.root=...`
#
# It also includes the Windows KenLM optional-import patch and uses `num_workers=1` (required by `persistent_workers=True`).

# %%
from __future__ import annotations
import os, sys, subprocess, time, re
from pathlib import Path

REPO_ROOT = Path.cwd()
assert (REPO_ROOT / "emg2qwerty").exists() and (REPO_ROOT / "config").exists(), \
    f"Open this notebook from the emg2qwerty_clean repo root. CWD={REPO_ROOT}"
print("Python:", sys.version.split()[0])
print("Repo root:", REPO_ROOT)
# Out:
# Python: 3.10.20
# Repo root: c:\Users\15855\OneDrive\UCLA\course\247A\Project\emg2qwerty_clean

# %% [markdown]
# ## 1) GPU sanity check

# %%
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if not torch.cuda.is_available():
    raise RuntimeError("CUDA not available in this kernel. Select the emg2qwerty kernel / reinstall CUDA torch.")
print("gpu:", torch.cuda.get_device_name(0))
print("torch CUDA:", torch.version.cuda)
# Out:
# torch: 2.10.0+cu128
# cuda available: True
# gpu: NVIDIA GeForce RTX 5080
# torch CUDA: 12.8

# %% [markdown]
# ## 2) DATA_DIR (folder containing `*.hdf5`)

# %%
DEFAULT_IN_REPO = REPO_ROOT / "data" / "subject_89335547"

# If your data is elsewhere, set this to the folder that directly contains *.hdf5
# EXTERNAL_DATA_DIR = r"C:\Users\...\subject_89335547"
EXTERNAL_DATA_DIR = None

data_dir = DEFAULT_IN_REPO if DEFAULT_IN_REPO.exists() else (Path(EXTERNAL_DATA_DIR) if EXTERNAL_DATA_DIR else DEFAULT_IN_REPO)
data_dir = data_dir.resolve()
print("DATA_DIR:", data_dir)

hdf5 = sorted(data_dir.glob("*.hdf5"))
print("Found .hdf5 files:", len(hdf5))
if len(hdf5) == 0:
    raise FileNotFoundError(
        f"No .hdf5 files found in {data_dir}\n"
        f"Put files at: {DEFAULT_IN_REPO} (recommended) OR set EXTERNAL_DATA_DIR."
    )

DATA_DIR_HYDRA = str(data_dir).replace("\\", "/")
print("DATA_DIR_HYDRA:", DATA_DIR_HYDRA)
print("Example files:", [p.name for p in hdf5[:5]])
# Out:
# DATA_DIR: C:\Users\15855\OneDrive\UCLA\course\247A\Project\emg2qwerty_clean\data\subject_89335547
# Found .hdf5 files: 18
# DATA_DIR_HYDRA: C:/Users/15855/OneDrive/UCLA/course/247A/Project/emg2qwerty_clean/data/subject_89335547
# Example files: ['2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5', '2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5', '2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5', '2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5', '2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5']

# %% [markdown]
# ## 3) Windows fix: make KenLM optional (greedy decoder doesn't need it)

# %%
import importlib

decoder_py = REPO_ROOT / "emg2qwerty" / "decoder.py"
assert decoder_py.exists(), f"Missing file: {decoder_py}"

def patch_decoder_make_kenlm_optional(path: Path) -> bool:
    txt = path.read_text(encoding="utf-8", errors="ignore")
    if "except ImportError" in txt and "kenlm = None" in txt:
        print("decoder.py already patched (kenlm optional).")
        return False

    pattern = r"(^|\n)\s*import\s+kenlm\s*(\n|$)"
    if re.search(pattern, txt):
        repl = r"\1try:\n    import kenlm  # type: ignore\nexcept ImportError:\n    kenlm = None  # type: ignore\n\2"
        txt2 = re.sub(pattern, repl, txt, count=1)
    elif "import kenlm" in txt:
        txt2 = txt.replace("import kenlm", "try:\n    import kenlm  # type: ignore\nexcept ImportError:\n    kenlm = None  # type: ignore", 1)
    else:
        print("No 'import kenlm' found; no patch needed.")
        return False

    path.write_text(txt2, encoding="utf-8", newline="\n")
    print("Patched decoder.py to make kenlm optional.")
    return True

try:
    import emg2qwerty.decoder  # noqa: F401
    print("Import emg2qwerty.decoder: OK")
except Exception as e:
    msg = repr(e)
    print("Import emg2qwerty.decoder failed:", msg)
    if "kenlm" in msg.lower():
        changed = patch_decoder_make_kenlm_optional(decoder_py)
        importlib.invalidate_caches()
        if changed:
            import emg2qwerty.decoder  # noqa: F401
            print("Re-import after patch: OK")
    else:
        raise
# Out:
# Import emg2qwerty.decoder: OK

# %% [markdown]
# ## 4) 1-epoch smoke test training (patch torch.load inside training process)

# %%
def run_and_print(cmd: list[str], cwd: Path) -> None:
    env = os.environ.copy()
    env["HYDRA_FULL_ERROR"] = "1"
    print(">>", " ".join(cmd))
    p = subprocess.run(cmd, cwd=str(cwd), env=env, text=True, capture_output=True)
    if p.stdout:
        print("----- STDOUT (tail) -----")
        print(p.stdout[-8000:])
    if p.stderr:
        print("----- STDERR (tail) -----")
        print(p.stderr[-8000:])
    if p.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {p.returncode}. See STDOUT/STDERR above.")

NUM_WORKERS = 1  # must be >0 due to persistent_workers=True upstream

patch_and_run = r'''
import torch, runpy
_old = torch.load
def _patched_load(*args, **kwargs):
    kwargs.setdefault("weights_only", False)
    return _old(*args, **kwargs)
torch.load = _patched_load
runpy.run_module("emg2qwerty.train", run_name="__main__")
'''.strip()

cmd = [
    sys.executable, "-c", patch_and_run,
    "user=single_user",
    f"dataset.root={DATA_DIR_HYDRA}",
    "trainer.accelerator=gpu", "trainer.devices=1",
    "trainer.max_epochs=1",
    f"num_workers={NUM_WORKERS}",
    "train=True",
    "decoder=ctc_greedy",
]

t0 = time.time()
run_and_print(cmd, cwd=REPO_ROOT)
print(f"OK. Elapsed: {time.time()-t0:.1f}s")
# Out:
# >> c:\Users\15855\.conda\envs\emg2qwerty\python.exe -c import torch, runpy
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__") user=single_user dataset.root=C:/Users/15855/OneDrive/UCLA/course/247A/Project/emg2qwerty_clean/data/subject_89335547 trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=1 num_workers=1 train=True decoder=ctc_greedy
# ----- STDOUT (tail) -----
#  96/127 [00:33<00:10,  2.82it/s, loss=126, v_num=0]
# Epoch 0:  76%|███████▋  | 97/127 [00:34<00:10,  2.83it/s, loss=126, v_num=0]
# Epoch 0:  76%|███████▋  | 97/127 [00:34<00:10,  2.83it/s, loss=126, v_num=0]
# Epoch 0:  77%|███████▋  | 98/127 [00:34<00:10,  2.83it/s, loss=126, v_num=0]
# Epoch 0:  77%|███████▋  | 98/127 [00:34<00:10,  2.83it/s, loss=125, v_num=0]
# Epoch 0:  78%|███████▊  | 99/127 [00:34<00:09,  2.83it/s, loss=125, v_num=0]
# Epoch 0:  78%|███████▊  | 99/127 [00:35<00:09,  2.83it/s, loss=128, v_num=0]
# Epoch 0:  79%|███████▊  | 100/127 [00:35<00:09,  2.83it/s, loss=128, v_num=0]
# Epoch 0:  79%|███████▊  | 100/127 [00:35<00:09,  2.83it/s, loss=131, v_num=0]
# Epoch 0:  80%|███████▉  | 101/127 [00:35<00:09,  2.83it/s, loss=131, v_num=0]
# Epoch 0:  80%|███████▉  | 101/127 [00:35<00:09,  2.83it/s, loss=130, v_num=0]
# Epoch 0:  80%|████████  | 102/127 [00:36<00:08,  2.83it/s, loss=130, v_num=0]
# Epoch 0:  80%|████████  | 102/127 [00:36<00:08,  2.82it/s, loss=130, v_num=0]
# Epoch 0:  81%|████████  | 103/127 [00:36<00:08,  2.83it/s, loss=130, v_num=0]
# Epoch 0:  81%|████████  | 103/127 [00:36<00:08,  2.82it/s, loss=130, v_num=0]
# Epoch 0:  82%|████████▏ | 104/127 [00:36<00:08,  2.83it/s, loss=130, v_num=0]
# Epoch 0:  82%|████████▏ | 104/127 [00:36<00:08,  2.83it/s, loss=127, v_num=0]
# Epoch 0:  83%|████████▎ | 105/127 [00:37<00:07,  2.83it/s, loss=127, v_num=0]
# Epoch 0:  83%|████████▎ | 105/127 [00:37<00:07,  2.83it/s, loss=123, v_num=0]
# Epoch 0:  83%|████████▎ | 106/127 [00:37<00:07,  2.83it/s, loss=123, v_num=0]
# Epoch 0:  83%|████████▎ | 106/127 [00:37<00:07,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  84%|████████▍ | 107/127 [00:37<00:07,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  84%|████████▍ | 107/127 [00:37<00:07,  2.83it/s, loss=115, v_num=0]
# Epoch 0:  85%|████████▌ | 108/127 [00:38<00:06,  2.83it/s, loss=115, v_num=0]
# Epoch 0:  85%|████████▌ | 108/127 [00:38<00:06,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  86%|████████▌ | 109/127 [00:38<00:06,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  86%|████████▌ | 109/127 [00:38<00:06,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  87%|████████▋ | 110/127 [00:38<00:05,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  87%|████████▋ | 110/127 [00:38<00:06,  2.83it/s, loss=120, v_num=0]
# Epoch 0:  87%|████████▋ | 111/127 [00:39<00:05,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  87%|████████▋ | 111/127 [00:39<00:05,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  88%|████████▊ | 112/127 [00:39<00:05,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  88%|████████▊ | 112/127 [00:39<00:05,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  89%|████████▉ | 113/127 [00:39<00:04,  2.84it/s, loss=120, v_num=0]
# Epoch 0:  89%|████████▉ | 113/127 [00:39<00:04,  2.84it/s, loss=124, v_num=0]
# Epoch 0:  90%|████████▉ | 114/127 [00:40<00:04,  2.84it/s, loss=124, v_num=0]
# Epoch 0:  90%|████████▉ | 114/127 [00:40<00:04,  2.84it/s, loss=124, v_num=0]
# Epoch 0:  91%|█████████ | 115/127 [00:40<00:04,  2.84it/s, loss=124, v_num=0]
# Epoch 0:  91%|█████████ | 115/127 [00:40<00:04,  2.84it/s, loss=127, v_num=0]
# Epoch 0:  91%|█████████▏| 116/127 [00:40<00:03,  2.84it/s, loss=127, v_num=0]
# Epoch 0:  91%|█████████▏| 116/127 [00:40<00:03,  2.84it/s, loss=123, v_num=0]
# Epoch 0:  92%|█████████▏| 117/127 [00:41<00:03,  2.84it/s, loss=123, v_num=0]
# Epoch 0:  92%|█████████▏| 117/127 [00:41<00:03,  2.84it/s, loss=123, v_num=0]
# Epoch 0:  93%|█████████▎| 118/127 [00:41<00:03,  2.84it/s, loss=123, v_num=0]
# Epoch 0:  93%|█████████▎| 118/127 [00:41<00:03,  2.84it/s, loss=126, v_num=0]
# Epoch 0:  94%|█████████▎| 119/127 [00:41<00:02,  2.85it/s, loss=126, v_num=0]
# Epoch 0:  94%|█████████▎| 119/127 [00:41<00:02,  2.84it/s, loss=123, v_num=0]
# Epoch 0:  94%|█████████▍| 120/127 [00:42<00:02,  2.85it/s, loss=123, v_num=0]
# Epoch 0:  94%|█████████▍| 120/127 [00:42<00:02,  2.85it/s, loss=124, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00, 16.05it/s]
# Epoch 0:  95%|█████████▌| 121/127 [00:42<00:02,  2.85it/s, loss=124, v_num=0]
#
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  5.92it/s]
# Epoch 0:  96%|█████████▌| 122/127 [00:42<00:01,  2.85it/s, loss=124, v_num=0]
#
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.93it/s]
# Epoch 0:  97%|█████████▋| 123/127 [00:43<00:01,  2.86it/s, loss=124, v_num=0]
#
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.74it/s]
# Epoch 0:  98%|█████████▊| 124/127 [00:43<00:01,  2.86it/s, loss=124, v_num=0]
#
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.49it/s]
# Epoch 0:  98%|█████████▊| 125/127 [00:43<00:00,  2.87it/s, loss=124, v_num=0]
#
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.32it/s]
# Epoch 0:  99%|█████████▉| 126/127 [00:43<00:00,  2.87it/s, loss=124, v_num=0]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.67it/s]
# Epoch 0: 100%|██████████| 127/127 [00:43<00:00,  2.89it/s, loss=124, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:43<00:00,  2.89it/s, loss=124, v_num=0]
#
#
# Epoch 0: 100%|██████████| 127/127 [00:43<00:00,  2.89it/s, loss=124, v_num=0]
# Epoch 0: 100%|██████████| 127/127 [00:44<00:00,  2.86it/s, loss=124, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00, 16.11it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  6.16it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  4.91it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  4.54it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:01<00:00,  4.45it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.27it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.56it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.54it/s]
# ┌───────────────────────────┬───────────────────────────┐
# │      Validate metric      │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │          val/CER          │    1364.7098388671875     │
# │          val/DER          │     1300.66455078125      │
# │          val/IER          │    0.04430660232901573    │
# │          val/SER          │     64.00088500976562     │
# │         val/loss          │    101.52149963378906     │
# └───────────────────────────┴───────────────────────────┘
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]
# ┌───────────────────────────┬───────────────────────────┐
# │        Test metric        │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │         test/CER          │     2134.08251953125      │
# │         test/DER          │     2083.120849609375     │
# │         test/IER          │            0.0            │
# │         test/SER          │     50.96174621582031     │
# │         test/loss         │    115.76605987548828     │
# └───────────────────────────┴───────────────────────────┘
# {'val_metrics': [{'val/loss': 101.52149963378906,
#                   'val/CER': 1364.7098388671875,
#                   'val/IER': 0.04430660232901573,
#                   'val/DER': 1300.66455078125,
#                   'val/SER': 64.00088500976562}],
#  'test_metrics': [{'test/loss': 115.76605987548828,
#                    'test/CER': 2134.08251953125,
#                    'test/IER': 0.0,
#                    'test/DER': 2083.120849609375,
#                    'test/SER': 50.96174621582031}],
#  'best_checkpoint': 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-13-15/checkpoints\\epoch=0-step=120.ckpt'}
#
# ----- STDERR (tail) -----
# Global seed set to 1501
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: c:\Users\15855\OneDrive\UCLA\course\247A\Project\emg2qwerty_clean\logs\2026-03-09\03-13-15\lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\models\self_supervised\amdim\amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\models\self_supervised\amdim\amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\losses\self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\hydra\_internal\instantiate\_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 5.3 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 5.3 M     Trainable params
# 0         Non-trainable params
# 5.3 M     Total params
# 21.173    Total estimated model params size (MB)
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0, global step 120: 'val/CER' reached 1364.70984 (best 1364.70984), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-13-15/checkpoints\\epoch=0-step=120.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=1` reached.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
#
# OK. Elapsed: 64.5s

# %% [markdown]
# ## 5) Full baseline run

# %%
EPOCHS = 40
NUM_WORKERS = 1

patch_and_run = r'''
import torch, runpy
_old = torch.load
def _patched_load(*args, **kwargs):
    kwargs.setdefault("weights_only", False)
    return _old(*args, **kwargs)
torch.load = _patched_load
runpy.run_module("emg2qwerty.train", run_name="__main__")
'''.strip()

cmd = [
    sys.executable, "-c", patch_and_run,
    "user=single_user",
    f"dataset.root={DATA_DIR_HYDRA}",
    "trainer.accelerator=gpu", "trainer.devices=1",
    f"trainer.max_epochs={EPOCHS}",
    f"num_workers={NUM_WORKERS}",
    "train=True",
    "decoder=ctc_greedy",
]

print("Ready. To run full training, run:")
print(" ".join(cmd))
run_and_print(cmd, cwd=REPO_ROOT)
# Out:
# Ready. To run full training, run:
# c:\Users\15855\.conda\envs\emg2qwerty\python.exe -c import torch, runpy
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__") user=single_user dataset.root=C:/Users/15855/OneDrive/UCLA/course/247A/Project/emg2qwerty_clean/data/subject_89335547 trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=40 num_workers=1 train=True decoder=ctc_greedy
# >> c:\Users\15855\.conda\envs\emg2qwerty\python.exe -c import torch, runpy
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__") user=single_user dataset.root=C:/Users/15855/OneDrive/UCLA/course/247A/Project/emg2qwerty_clean/data/subject_89335547 trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=40 num_workers=1 train=True decoder=ctc_greedy
# ----- STDOUT (tail) -----
# /s, loss=0.721, v_num=0]
# Epoch 39:  77%|███████▋  | 98/127 [00:58<00:17,  1.66it/s, loss=0.721, v_num=0]
# Epoch 39:  77%|███████▋  | 98/127 [00:58<00:17,  1.66it/s, loss=0.717, v_num=0]
# Epoch 39:  78%|███████▊  | 99/127 [00:59<00:16,  1.66it/s, loss=0.717, v_num=0]
# Epoch 39:  78%|███████▊  | 99/127 [00:59<00:16,  1.66it/s, loss=0.718, v_num=0]
# Epoch 39:  79%|███████▊  | 100/127 [01:00<00:16,  1.66it/s, loss=0.718, v_num=0]
# Epoch 39:  79%|███████▊  | 100/127 [01:00<00:16,  1.66it/s, loss=0.721, v_num=0]
# Epoch 39:  80%|███████▉  | 101/127 [01:00<00:15,  1.66it/s, loss=0.721, v_num=0]
# Epoch 39:  80%|███████▉  | 101/127 [01:01<00:15,  1.65it/s, loss=0.721, v_num=0]
# Epoch 39:  80%|████████  | 102/127 [01:01<00:15,  1.65it/s, loss=0.721, v_num=0]
# Epoch 39:  80%|████████  | 102/127 [01:01<00:15,  1.65it/s, loss=0.726, v_num=0]
# Epoch 39:  81%|████████  | 103/127 [01:02<00:14,  1.65it/s, loss=0.726, v_num=0]
# Epoch 39:  81%|████████  | 103/127 [01:02<00:14,  1.65it/s, loss=0.73, v_num=0]
# Epoch 39:  82%|████████▏ | 104/127 [01:03<00:13,  1.65it/s, loss=0.73, v_num=0]
# Epoch 39:  82%|████████▏ | 104/127 [01:03<00:13,  1.65it/s, loss=0.73, v_num=0]
# Epoch 39:  83%|████████▎ | 105/127 [01:03<00:13,  1.65it/s, loss=0.73, v_num=0]
# Epoch 39:  83%|████████▎ | 105/127 [01:03<00:13,  1.65it/s, loss=0.727, v_num=0]
# Epoch 39:  83%|████████▎ | 106/127 [01:04<00:12,  1.65it/s, loss=0.727, v_num=0]
# Epoch 39:  83%|████████▎ | 106/127 [01:04<00:12,  1.64it/s, loss=0.721, v_num=0]
# Epoch 39:  84%|████████▍ | 107/127 [01:05<00:12,  1.64it/s, loss=0.721, v_num=0]
# Epoch 39:  84%|████████▍ | 107/127 [01:05<00:12,  1.64it/s, loss=0.718, v_num=0]
# Epoch 39:  85%|████████▌ | 108/127 [01:05<00:11,  1.64it/s, loss=0.718, v_num=0]
# Epoch 39:  85%|████████▌ | 108/127 [01:05<00:11,  1.64it/s, loss=0.724, v_num=0]
# Epoch 39:  86%|████████▌ | 109/127 [01:06<00:10,  1.64it/s, loss=0.724, v_num=0]
# Epoch 39:  86%|████████▌ | 109/127 [01:06<00:10,  1.64it/s, loss=0.717, v_num=0]
# Epoch 39:  87%|████████▋ | 110/127 [01:07<00:10,  1.64it/s, loss=0.717, v_num=0]
# Epoch 39:  87%|████████▋ | 110/127 [01:07<00:10,  1.64it/s, loss=0.72, v_num=0]
# Epoch 39:  87%|████████▋ | 111/127 [01:07<00:09,  1.64it/s, loss=0.72, v_num=0]
# Epoch 39:  87%|████████▋ | 111/127 [01:07<00:09,  1.64it/s, loss=0.722, v_num=0]
# Epoch 39:  88%|████████▊ | 112/127 [01:08<00:09,  1.64it/s, loss=0.722, v_num=0]
# Epoch 39:  88%|████████▊ | 112/127 [01:08<00:09,  1.63it/s, loss=0.732, v_num=0]
# Epoch 39:  89%|████████▉ | 113/127 [01:09<00:08,  1.63it/s, loss=0.732, v_num=0]
# Epoch 39:  89%|████████▉ | 113/127 [01:09<00:08,  1.63it/s, loss=0.734, v_num=0]
# Epoch 39:  90%|████████▉ | 114/127 [01:09<00:07,  1.63it/s, loss=0.734, v_num=0]
# Epoch 39:  90%|████████▉ | 114/127 [01:09<00:07,  1.63it/s, loss=0.745, v_num=0]
# Epoch 39:  91%|█████████ | 115/127 [01:10<00:07,  1.63it/s, loss=0.745, v_num=0]
# Epoch 39:  91%|█████████ | 115/127 [01:10<00:07,  1.63it/s, loss=0.739, v_num=0]
# Epoch 39:  91%|█████████▏| 116/127 [01:11<00:06,  1.63it/s, loss=0.739, v_num=0]
# Epoch 39:  91%|█████████▏| 116/127 [01:11<00:06,  1.63it/s, loss=0.73, v_num=0]
# Epoch 39:  92%|█████████▏| 117/127 [01:11<00:06,  1.63it/s, loss=0.73, v_num=0]
# Epoch 39:  92%|█████████▏| 117/127 [01:11<00:06,  1.63it/s, loss=0.732, v_num=0]
# Epoch 39:  93%|█████████▎| 118/127 [01:12<00:05,  1.63it/s, loss=0.732, v_num=0]
# Epoch 39:  93%|█████████▎| 118/127 [01:12<00:05,  1.62it/s, loss=0.729, v_num=0]
# Epoch 39:  94%|█████████▎| 119/127 [01:13<00:04,  1.62it/s, loss=0.729, v_num=0]
# Epoch 39:  94%|█████████▎| 119/127 [01:13<00:04,  1.62it/s, loss=0.732, v_num=0]
# Epoch 39:  94%|█████████▍| 120/127 [01:13<00:04,  1.63it/s, loss=0.732, v_num=0]
# Epoch 39:  94%|█████████▍| 120/127 [01:13<00:04,  1.62it/s, loss=0.727, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
#
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00, 20.08it/s]
# Epoch 39:  95%|█████████▌| 121/127 [01:14<00:03,  1.62it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:01,  3.33it/s]
# Epoch 39:  96%|█████████▌| 122/127 [01:15<00:03,  1.62it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:01<00:01,  2.60it/s]
# Epoch 39:  97%|█████████▋| 123/127 [01:15<00:02,  1.63it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:01<00:01,  2.32it/s]
# Epoch 39:  98%|█████████▊| 124/127 [01:16<00:01,  1.63it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:02<00:00,  2.20it/s]
# Epoch 39:  98%|█████████▊| 125/127 [01:16<00:01,  1.63it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:02<00:00,  2.10it/s]
# Epoch 39:  99%|█████████▉| 126/127 [01:17<00:00,  1.63it/s, loss=0.727, v_num=0]
#
# Validation DataLoader 0: 100%|██████████| 7/7 [00:03<00:00,  2.22it/s]
# Epoch 39: 100%|██████████| 127/127 [01:17<00:00,  1.63it/s, loss=0.727, v_num=0]
# Epoch 39: 100%|██████████| 127/127 [01:17<00:00,  1.63it/s, loss=0.727, v_num=0]
#
#
# Epoch 39: 100%|██████████| 127/127 [01:17<00:00,  1.63it/s, loss=0.727, v_num=0]
# Epoch 39: 100%|██████████| 127/127 [01:17<00:00,  1.63it/s, loss=0.727, v_num=0]
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/7 [00:00<?, ?it/s]
# Validation DataLoader 0:  14%|█▍        | 1/7 [00:00<00:00, 18.27it/s]
# Validation DataLoader 0:  29%|██▊       | 2/7 [00:00<00:00,  7.11it/s]
# Validation DataLoader 0:  43%|████▎     | 3/7 [00:00<00:00,  5.88it/s]
# Validation DataLoader 0:  57%|█████▋    | 4/7 [00:00<00:00,  5.40it/s]
# Validation DataLoader 0:  71%|███████▏  | 5/7 [00:00<00:00,  5.08it/s]
# Validation DataLoader 0:  86%|████████▌ | 6/7 [00:01<00:00,  4.87it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.64it/s]
# Validation DataLoader 0: 100%|██████████| 7/7 [00:01<00:00,  4.62it/s]
# ┌───────────────────────────┬───────────────────────────┐
# │      Validate metric      │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │          val/CER          │    23.172351837158203     │
# │          val/DER          │    2.0381035804748535     │
# │          val/IER          │     6.71245002746582      │
# │          val/SER          │    14.421798706054688     │
# │         val/loss          │    0.7796502113342285     │
# └───────────────────────────┴───────────────────────────┘
#
# Testing: 0it [00:00, ?it/s]
# Testing:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# Testing DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# ┌───────────────────────────┬───────────────────────────┐
# │        Test metric        │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │         test/CER          │    24.248973846435547     │
# │         test/DER          │    2.1180031299591064     │
# │         test/IER          │     5.81370210647583      │
# │         test/SER          │     16.31726837158203     │
# │         test/loss         │    0.7763050198554993     │
# └───────────────────────────┴───────────────────────────┘
# {'val_metrics': [{'val/loss': 0.7796502113342285,
#                   'val/CER': 23.172351837158203,
#                   'val/IER': 6.71245002746582,
#                   'val/DER': 2.0381035804748535,
#                   'val/SER': 14.421798706054688}],
#  'test_metrics': [{'test/loss': 0.7763050198554993,
#                    'test/CER': 24.248973846435547,
#                    'test/IER': 5.81370210647583,
#                    'test/DER': 2.1180031299591064,
#                    'test/SER': 16.31726837158203}],
#  'best_checkpoint': 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=35-step=4320.ckpt'}
#
# ----- STDERR (tail) -----
# s
# 5.3 M     Total params
# 21.173    Total estimated model params size (MB)
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0, global step 120: 'val/CER' reached 1364.66553 (best 1364.66553), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=0-step=120.ckpt' as top 1
# Epoch 1, global step 240: 'val/CER' reached 100.00000 (best 100.00000), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=1-step=240.ckpt' as top 1
# Epoch 2, global step 360: 'val/CER' was not in top 1
# Epoch 3, global step 480: 'val/CER' was not in top 1
# Epoch 4, global step 600: 'val/CER' was not in top 1
# Epoch 5, global step 720: 'val/CER' was not in top 1
# Epoch 6, global step 840: 'val/CER' was not in top 1
# Epoch 7, global step 960: 'val/CER' was not in top 1
# Epoch 8, global step 1080: 'val/CER' was not in top 1
# Epoch 9, global step 1200: 'val/CER' reached 98.42712 (best 98.42712), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=9-step=1200.ckpt' as top 1
# Epoch 10, global step 1320: 'val/CER' reached 94.61674 (best 94.61674), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=10-step=1320.ckpt' as top 1
# Epoch 11, global step 1440: 'val/CER' reached 85.64466 (best 85.64466), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=11-step=1440.ckpt' as top 1
# Epoch 12, global step 1560: 'val/CER' reached 83.60656 (best 83.60656), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=12-step=1560.ckpt' as top 1
# Epoch 13, global step 1680: 'val/CER' reached 73.94772 (best 73.94772), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=13-step=1680.ckpt' as top 1
# Epoch 14, global step 1800: 'val/CER' reached 69.98228 (best 69.98228), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=14-step=1800.ckpt' as top 1
# Epoch 15, global step 1920: 'val/CER' reached 68.09924 (best 68.09924), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=15-step=1920.ckpt' as top 1
# Epoch 16, global step 2040: 'val/CER' reached 64.02304 (best 64.02304), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=16-step=2040.ckpt' as top 1
# Epoch 17, global step 2160: 'val/CER' reached 49.88923 (best 49.88923), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=17-step=2160.ckpt' as top 1
# Epoch 18, global step 2280: 'val/CER' reached 47.58529 (best 47.58529), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=18-step=2280.ckpt' as top 1
# Epoch 19, global step 2400: 'val/CER' reached 35.79974 (best 35.79974), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=19-step=2400.ckpt' as top 1
# Epoch 20, global step 2520: 'val/CER' reached 34.86930 (best 34.86930), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=20-step=2520.ckpt' as top 1
# Epoch 21, global step 2640: 'val/CER' reached 33.05273 (best 33.05273), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=21-step=2640.ckpt' as top 1
# Epoch 22, global step 2760: 'val/CER' was not in top 1
# Epoch 23, global step 2880: 'val/CER' reached 29.15374 (best 29.15374), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=23-step=2880.ckpt' as top 1
# Epoch 24, global step 3000: 'val/CER' was not in top 1
# Epoch 25, global step 3120: 'val/CER' reached 27.84670 (best 27.84670), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=25-step=3120.ckpt' as top 1
# Epoch 26, global step 3240: 'val/CER' reached 27.33717 (best 27.33717), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=26-step=3240.ckpt' as top 1
# Epoch 27, global step 3360: 'val/CER' reached 26.78334 (best 26.78334), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=27-step=3360.ckpt' as top 1
# Epoch 28, global step 3480: 'val/CER' reached 25.49845 (best 25.49845), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=28-step=3480.ckpt' as top 1
# Epoch 29, global step 3600: 'val/CER' was not in top 1
# Epoch 30, global step 3720: 'val/CER' reached 25.09969 (best 25.09969), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=30-step=3720.ckpt' as top 1
# Epoch 31, global step 3840: 'val/CER' reached 24.70093 (best 24.70093), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=31-step=3840.ckpt' as top 1
# Epoch 32, global step 3960: 'val/CER' was not in top 1
# Epoch 33, global step 4080: 'val/CER' reached 23.96987 (best 23.96987), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=33-step=4080.ckpt' as top 1
# Epoch 34, global step 4200: 'val/CER' was not in top 1
# Epoch 35, global step 4320: 'val/CER' reached 23.17235 (best 23.17235), saving model to 'c:\\Users\\15855\\OneDrive\\UCLA\\course\\247A\\Project\\emg2qwerty_clean\\logs\\2026-03-09\\03-18-40/checkpoints\\epoch=35-step=4320.ckpt' as top 1
# Epoch 36, global step 4440: 'val/CER' was not in top 1
# Epoch 37, global step 4560: 'val/CER' was not in top 1
# Epoch 38, global step 4680: 'val/CER' was not in top 1
# Epoch 39, global step 4800: 'val/CER' was not in top 1
# `Trainer.fit` stopped: `max_epochs=40` reached.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 32 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
