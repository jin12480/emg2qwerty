# %% [markdown]
# # emg2qwerty Baseline Runner
#
#
# This notebook runs:
# `python -c "<patch torch.load; runpy.run_module('emg2qwerty.train', run_name='__main__')>" user=... dataset.root=...`
#
# It also includes the Windows KenLM optional-import patch. **DataLoader** uses multiple `num_workers` on Windows with `persistent_workers=False` in code so the GPU stays fed; default config uses larger batch + bf16 for higher GPU util.

# %%
from __future__ import annotations
import os, sys, subprocess, time, re
from pathlib import Path

REPO_ROOT = Path.cwd()
assert (REPO_ROOT / "emg2qwerty").exists() and (REPO_ROOT / "config").exists(), \
    f"Open this notebook from the emg2qwerty_clean repo root. CWD={REPO_ROOT}"
print("Python:", sys.version.split()[0])
print("Repo root:", REPO_ROOT)
# Out:
# Python: 3.10.20
# Repo root: c:\Users\15855\Desktop\emg2qwerty

# %% [markdown]
# ## 1) GPU sanity check

# %%
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
if not torch.cuda.is_available():
    raise RuntimeError("CUDA not available in this kernel. Select the emg2qwerty kernel / reinstall CUDA torch.")
print("gpu:", torch.cuda.get_device_name(0))
print("torch CUDA:", torch.version.cuda)
# Out:
# torch: 2.10.0+cu128
# cuda available: True
# gpu: NVIDIA GeForce RTX 5080
# torch CUDA: 12.8

# %% [markdown]
# ## 2) DATA_DIR (required)
#
# Put the dataset files here:
#
# - `data/subject_89335547/*.hdf5`
#
# This notebook assumes you are running from the repo root, so the full path is:
#
# - `REPO_ROOT / data / subject_89335547`

# %%
# Fixed location (required): repo_root/data/subject_89335547/*.hdf5
data_dir = (REPO_ROOT / "data" / "subject_89335547").resolve()
print("DATA_DIR:", data_dir)

if not data_dir.exists():
    raise FileNotFoundError(
        f"Missing folder: {data_dir}\n"
        "Put the dataset here: data/subject_89335547/*.hdf5"
    )

hdf5 = sorted(data_dir.glob("*.hdf5"))
print("Found .hdf5 files:", len(hdf5))
if len(hdf5) == 0:
    raise FileNotFoundError(
        f"No .hdf5 files found in {data_dir}\n"
        "Put the dataset here: data/subject_89335547/*.hdf5"
    )

DATA_DIR_HYDRA = str(data_dir).replace("\\", "/")
print("DATA_DIR_HYDRA:", DATA_DIR_HYDRA)
# Out:
# DATA_DIR: C:\Users\15855\Desktop\emg2qwerty\data\subject_89335547
# Found .hdf5 files: 18
# DATA_DIR_HYDRA: C:/Users/15855/Desktop/emg2qwerty/data/subject_89335547

# %% [markdown]
# ## 3) KenLM (optional)
#
# If you always run with `decoder=ctc_greedy`, you **do not need KenLM** on Windows.
# This repo's `emg2qwerty/decoder.py` already treats KenLM as an optional dependency.

# %%
# No KenLM setup needed if you use greedy decoding.
# Sanity: this should import even if `kenlm` isn't installed.
import emg2qwerty.decoder  # noqa: F401
print("Import emg2qwerty.decoder: OK")
# Out:
# Import emg2qwerty.decoder: OK

# %% [markdown]
# ## 4) 1-epoch smoke test training (patch torch.load inside training process)

# %%
from emg2qwerty.notebook_utils import run_and_print

# # Smoke test: use num_workers=1 on Windows — num_workers>0 with HDF5 often crashes workers
# # ("DataLoader worker exited unexpectedly"). Full run cell can use 8 if stable on your machine.
# NUM_WORKERS = 1
# BATCH_SIZE = 8  # increase if no OOM (e.g. 96); decrease if CUDA OOM

# patch_and_run = r'''
# import torch, runpy
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__")
# '''.strip()

# cmd = [
#     sys.executable, "-c", patch_and_run,
#     "user=single_user",
#     f"dataset.root={DATA_DIR_HYDRA}",
#     "trainer.accelerator=gpu", "trainer.devices=1",
#     "trainer.max_epochs=1",
#     "trainer.precision=bf16",
#     f"batch_size={BATCH_SIZE}",
#     f"num_workers={NUM_WORKERS}",
#     "train=True",
#     "decoder=ctc_greedy",
# ]

# t0 = time.time()
# run_and_print(cmd, cwd=REPO_ROOT)
# print(f"OK. Elapsed: {time.time()-t0:.1f}s")

# %% [markdown]
# ## 5) Full baseline run

# %%
# --- Repro ~23/24 CER run (03-18-40) but faster GPU util ---
# That run used: batch 32, fp32, lr 1e-3, warmup 10, eta_min 1e-6, num_workers=1 (GPU starved).
# Here: SAME hyperparams, num_workers=8 + cudnn.benchmark + TF32 matmul to feed 5080.
# Data: if you still have emg2qwerty_clean copy, set EXTERNAL_DATA_ROOT below for identical files.
#
EXTERNAL_DATA_ROOT = None  # e.g. r"C:/Users/.../emg2qwerty_clean/data/subject_89335547"
if EXTERNAL_DATA_ROOT:
    DATA_DIR_HYDRA = str(Path(EXTERNAL_DATA_ROOT).resolve()).replace("\\", "/")
    print("Using EXTERNAL_DATA_ROOT:", DATA_DIR_HYDRA)

EPOCHS = 40
NUM_WORKERS = 10  
BATCH_SIZE = 8
LR = "5e-4"
WARMUP = 10

patch_and_run = r'''
import torch, runpy
# Higher GPU util + faster step time (same fp32 recipe as 03-18-40)
torch.backends.cudnn.benchmark = True
try:
    torch.set_float32_matmul_precision("high")  # TF32 on RTX; small numerical diff possible
except Exception:
    pass
_old = torch.load
def _patched_load(*args, **kwargs):
    kwargs.setdefault("weights_only", False)
    return _old(*args, **kwargs)
torch.load = _patched_load
runpy.run_module("emg2qwerty.train", run_name="__main__")
'''.strip()

cmd = [
    sys.executable, "-c", patch_and_run,
    "user=single_user",
    f"dataset.root={DATA_DIR_HYDRA}",
    "trainer.accelerator=gpu", "trainer.devices=1",
    f"trainer.max_epochs={EPOCHS}",
    f"batch_size={BATCH_SIZE}",
    f"num_workers={NUM_WORKERS}",
    f"optimizer.lr={LR}",
    f"lr_scheduler.scheduler.warmup_epochs={WARMUP}",
    "lr_scheduler.scheduler.eta_min=1e-6",
    "transforms=log_spectrogram_no_specaug",
    "train=True",
    "decoder=ctc_greedy",
]

print(f"Ready. Repro 03-18-40 recipe + fast dataloader, {EPOCHS} ep batch={BATCH_SIZE}:")
print(" ".join(cmd))
run_and_print(cmd, cwd=REPO_ROOT)
# Out:
# Ready. Repro 03-18-40 recipe + fast dataloader, 40 ep batch=8:
# c:\Users\15855\.conda\envs\emg2qwerty\python.exe -c import torch, runpy
# # Higher GPU util + faster step time (same fp32 recipe as 03-18-40)
# torch.backends.cudnn.benchmark = True
# try:
#     torch.set_float32_matmul_precision("high")  # TF32 on RTX; small numerical diff possible
# except Exception:
#     pass
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__") user=single_user dataset.root=C:/Users/15855/Desktop/emg2qwerty/data/subject_89335547 trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=40 batch_size=8 num_workers=10 optimizer.lr=5e-4 lr_scheduler.scheduler.warmup_epochs=10 lr_scheduler.scheduler.eta_min=1e-6 transforms=log_spectrogram_no_specaug train=True decoder=ctc_greedy
# >> c:\Users\15855\.conda\envs\emg2qwerty\python.exe -c import torch, runpy
# # Higher GPU util + faster step time (same fp32 recipe as 03-18-40)
# torch.backends.cudnn.benchmark = True
# try:
#     torch.set_float32_matmul_precision("high")  # TF32 on RTX; small numerical diff possible
# except Exception:
#     pass
# _old = torch.load
# def _patched_load(*args, **kwargs):
#     kwargs.setdefault("weights_only", False)
#     return _old(*args, **kwargs)
# torch.load = _patched_load
# runpy.run_module("emg2qwerty.train", run_name="__main__") user=single_user dataset.root=C:/Users/15855/Desktop/emg2qwerty/data/subject_89335547 trainer.accelerator=gpu trainer.devices=1 trainer.max_epochs=40 batch_size=8 num_workers=10 optimizer.lr=5e-4 lr_scheduler.scheduler.warmup_epochs=10 lr_scheduler.scheduler.eta_min=1e-6 transforms=log_spectrogram_no_specaug train=True decoder=ctc_greedy
# Log file: c:\Users\15855\Desktop\emg2qwerty\logs\notebook_runs\train_2026-03-10_02-12-28.log
# [2026-03-10 02:12:31,931][__main__][INFO] -
# Config:
# user: single_user
# dataset:
#   train:
#   - user: 89335547
#     session: 2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622863166-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627003020-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626916256-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627004019-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622885888-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626917264-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622889105-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-22-1627001995-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-06-05-1622884635-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   - user: 89335547
#     session: 2021-07-21-1626915176-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   val:
#   - user: 89335547
#     session: 2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   test:
#   - user: 89335547
#     session: 2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f
#   root: C:/Users/15855/Desktop/emg2qwerty/data/subject_89335547
# transforms:
#   train:
#   - _target_: emg2qwerty.transforms.ToTensor
#     fields:
#     - emg_left
#     - emg_right
#   - _target_: emg2qwerty.transforms.ForEach
#     transform:
#       _target_: emg2qwerty.transforms.RandomBandRotation
#       offsets:
#       - -1
#       - 0
#       - 1
#   - _target_: emg2qwerty.transforms.TemporalAlignmentJitter
#     max_offset: 120
#   - _target_: emg2qwerty.transforms.LogSpectrogram
#     n_fft: 64
#     hop_length: 16
#   val:
#   - _target_: emg2qwerty.transforms.ToTensor
#     fields:
#     - emg_left
#     - emg_right
#   - _target_: emg2qwerty.transforms.LogSpectrogram
#     n_fft: 64
#     hop_length: 16
#   test:
#   - _target_: emg2qwerty.transforms.ToTensor
#     fields:
#     - emg_left
#     - emg_right
#   - _target_: emg2qwerty.transforms.LogSpectrogram
#     n_fft: 64
#     hop_length: 16
# module:
#   _target_: emg2qwerty.lightning.TDSConvCTCModule
#   in_features: 528
#   mlp_features:
#   - 384
#   block_channels:
#   - 24
#   - 24
#   - 24
#   - 24
#   kernel_width: 32
# datamodule:
#   _target_: emg2qwerty.lightning.WindowedEMGDataModule
#   window_length: 8000
#   padding:
#   - 1800
#   - 200
# optimizer:
#   _target_: torch.optim.Adam
#   lr: 0.0005
# lr_scheduler:
#   scheduler:
#     _target_: pl_bolts.optimizers.lr_scheduler.LinearWarmupCosineAnnealingLR
#     warmup_epochs: 10
#     max_epochs: ${trainer.max_epochs}
#     warmup_start_lr: 1.0e-08
#     eta_min: 1.0e-06
#   interval: epoch
# decoder:
#   _target_: emg2qwerty.decoder.CTCGreedyDecoder
# seed: 1501
# batch_size: 8
# num_workers: 10
# train: true
# checkpoint: null
# monitor_metric: val/CER
# monitor_mode: min
# trainer:
#   accelerator: gpu
#   devices: 1
#   num_nodes: 1
#   max_epochs: 40
#   default_root_dir: ${hydra:runtime.output_dir}
# callbacks:
# - _target_: pytorch_lightning.callbacks.LearningRateMonitor
# - _target_: pytorch_lightning.callbacks.ModelCheckpoint
#   dirpath: ${hydra:runtime.output_dir}/checkpoints
#   monitor: ${monitor_metric}
#   mode: ${monitor_mode}
#   save_last: true
#   verbose: true
#
# Global seed set to 1501
# [2026-03-10 02:12:31,934][__main__][INFO] - Instantiating LightningModule {'_target_': 'emg2qwerty.lightning.TDSConvCTCModule', 'in_features': 528, 'mlp_features': [384], 'block_channels': [24, 24, 24, 24], 'kernel_width': 32}
# [2026-03-10 02:12:32,054][__main__][INFO] - Instantiating LightningDataModule {'_target_': 'emg2qwerty.lightning.WindowedEMGDataModule', 'window_length': 8000, 'padding': [1800, 200]}
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: c:\Users\15855\Desktop\emg2qwerty\logs\2026-03-10\02-12-31\lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\models\self_supervised\amdim\amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\models\self_supervised\amdim\amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\pl_bolts\losses\self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)
# c:\Users\15855\.conda\envs\emg2qwerty\lib\site-packages\hydra\_internal\instantiate\_instantiate2.py:92: UnderReviewWarning: The feature LinearWarmupCosineAnnealingLR is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   return _target_(*args, **kwargs)
#
#   | Name     | Type       | Params
# ----------------------------------------
# 0 | model    | Sequential | 5.3 M
# 1 | ctc_loss | CTCLoss    | 0
# 2 | metrics  | ModuleDict | 0
# ----------------------------------------
# 5.3 M     Trainable params
# 0         Non-trainable params
# 5.3 M     Total params
# 21.173    Total estimated model params size (MB)
# [epoch 0] val loss=198.3807  val/CER=n/a
# [epoch 0] val loss=100.0699  val/CER=n/a
# [epoch 0] train loss=121.4232  train/CER=n/a
# Epoch 0, global step 480: 'val/CER' reached 1428.71069 (best 1428.71069), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=0-step=480.ckpt' as top 1
# [epoch 1] val loss=3.3036  val/CER=1428.7107
# [epoch 1] train loss=3.3175  train/CER=1748.4771
# Epoch 1, global step 960: 'val/CER' reached 100.00000 (best 100.00000), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=1-step=960.ckpt' as top 1
# [epoch 2] val loss=3.0905  val/CER=100.0000
# [epoch 2] train loss=3.0024  train/CER=103.5374
# Epoch 2, global step 1440: 'val/CER' was not in top 1
# [epoch 3] val loss=2.9993  val/CER=100.0000
# [epoch 3] train loss=3.1842  train/CER=100.0000
# Epoch 3, global step 1920: 'val/CER' was not in top 1
# [epoch 4] val loss=2.8644  val/CER=100.0000
# [epoch 4] train loss=2.9281  train/CER=100.0000
# Epoch 4, global step 2400: 'val/CER' reached 99.95570 (best 99.95570), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=4-step=2400.ckpt' as top 1
# [epoch 5] val loss=2.6602  val/CER=99.9557
# [epoch 5] train loss=2.5997  train/CER=99.9807
# Epoch 5, global step 2880: 'val/CER' reached 99.64555 (best 99.64555), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=5-step=2880.ckpt' as top 1
# [epoch 6] val loss=2.4082  val/CER=99.6455
# [epoch 6] train loss=2.7364  train/CER=99.7054
# Epoch 6, global step 3360: 'val/CER' reached 94.10722 (best 94.10722), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=6-step=3360.ckpt' as top 1
# [epoch 7] val loss=2.1129  val/CER=94.1072
# [epoch 7] train loss=1.9927  train/CER=96.9394
# Epoch 7, global step 3840: 'val/CER' reached 89.61010 (best 89.61010), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=7-step=3840.ckpt' as top 1
# [epoch 8] val loss=1.9892  val/CER=89.6101
# [epoch 8] train loss=2.4516  train/CER=91.2580
# Epoch 8, global step 4320: 'val/CER' reached 72.75144 (best 72.75144), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=8-step=4320.ckpt' as top 1
# [epoch 9] val loss=1.6949  val/CER=72.7514
# [epoch 9] train loss=1.4760  train/CER=85.2312
# Epoch 9, global step 4800: 'val/CER' reached 67.70049 (best 67.70049), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=9-step=4800.ckpt' as top 1
# [epoch 10] val loss=1.5654  val/CER=67.7005
# [epoch 10] train loss=1.7343  train/CER=73.3163
# Epoch 10, global step 5280: 'val/CER' reached 59.08286 (best 59.08286), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=10-step=5280.ckpt' as top 1
# [epoch 11] val loss=1.3300  val/CER=59.0829
# [epoch 11] train loss=1.6678  train/CER=62.9462
# Epoch 11, global step 5760: 'val/CER' reached 46.96500 (best 46.96500), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=11-step=5760.ckpt' as top 1
# [epoch 12] val loss=1.2425  val/CER=46.9650
# [epoch 12] train loss=1.2252  train/CER=57.3876
# Epoch 12, global step 6240: 'val/CER' reached 41.71466 (best 41.71466), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=12-step=6240.ckpt' as top 1
# [epoch 13] val loss=1.1039  val/CER=41.7147
# [epoch 13] train loss=1.4759  train/CER=47.1566
# Epoch 13, global step 6720: 'val/CER' reached 35.55605 (best 35.55605), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=13-step=6720.ckpt' as top 1
# [epoch 14] val loss=1.0119  val/CER=35.5560
# [epoch 14] train loss=1.0513  train/CER=40.3198
# Epoch 14, global step 7200: 'val/CER' reached 32.83119 (best 32.83119), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=14-step=7200.ckpt' as top 1
# [epoch 15] val loss=0.9795  val/CER=32.8312
# [epoch 15] train loss=1.0506  train/CER=35.7464
# Epoch 15, global step 7680: 'val/CER' reached 30.94816 (best 30.94816), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=15-step=7680.ckpt' as top 1
# [epoch 16] val loss=0.9045  val/CER=30.9482
# [epoch 16] train loss=1.0194  train/CER=33.3480
# Epoch 16, global step 8160: 'val/CER' reached 28.22330 (best 28.22330), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=16-step=8160.ckpt' as top 1
# [epoch 17] val loss=0.8393  val/CER=28.2233
# [epoch 17] train loss=0.9720  train/CER=29.8086
# Epoch 17, global step 8640: 'val/CER' reached 24.36863 (best 24.36863), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=17-step=8640.ckpt' as top 1
# [epoch 18] val loss=0.8447  val/CER=24.3686
# [epoch 18] train loss=0.5822  train/CER=27.1892
# Epoch 18, global step 9120: 'val/CER' was not in top 1
# [epoch 19] val loss=0.8872  val/CER=24.4351
# [epoch 19] train loss=0.7381  train/CER=25.5801
# Epoch 19, global step 9600: 'val/CER' was not in top 1
# [epoch 20] val loss=0.8726  val/CER=25.4984
# [epoch 20] train loss=0.5309  train/CER=24.0035
# Epoch 20, global step 10080: 'val/CER' was not in top 1
# [epoch 21] val loss=0.7727  val/CER=25.3212
# [epoch 21] train loss=0.6307  train/CER=22.6492
# Epoch 21, global step 10560: 'val/CER' reached 22.92867 (best 22.92867), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=21-step=10560.ckpt' as top 1
# [epoch 22] val loss=0.7663  val/CER=22.9287
# [epoch 22] train loss=0.7060  train/CER=21.4739
# Epoch 22, global step 11040: 'val/CER' reached 22.24191 (best 22.24191), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=22-step=11040.ckpt' as top 1
# [epoch 23] val loss=0.7297  val/CER=22.2419
# [epoch 23] train loss=0.4913  train/CER=20.4394
# Epoch 23, global step 11520: 'val/CER' reached 19.93797 (best 19.93797), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=23-step=11520.ckpt' as top 1
# [epoch 24] val loss=0.7301  val/CER=19.9380
# [epoch 24] train loss=0.5091  train/CER=18.9577
# Epoch 24, global step 12000: 'val/CER' was not in top 1
# [epoch 25] val loss=0.7269  val/CER=20.8241
# [epoch 25] train loss=0.7413  train/CER=17.6859
# Epoch 25, global step 12480: 'val/CER' was not in top 1
# [epoch 26] val loss=0.7426  val/CER=20.2703
# [epoch 26] train loss=0.3301  train/CER=16.2894
# Epoch 26, global step 12960: 'val/CER' was not in top 1
# [epoch 27] val loss=0.7272  val/CER=20.2481
# [epoch 27] train loss=0.4002  train/CER=14.5024
# Epoch 27, global step 13440: 'val/CER' reached 19.29552 (best 19.29552), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=27-step=13440.ckpt' as top 1
# [epoch 28] val loss=0.7121  val/CER=19.2955
# [epoch 28] train loss=0.5352  train/CER=13.2784
# Epoch 28, global step 13920: 'val/CER' reached 18.05494 (best 18.05494), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=28-step=13920.ckpt' as top 1
# [epoch 29] val loss=0.7190  val/CER=18.0549
# [epoch 29] train loss=0.2068  train/CER=11.9792
# Epoch 29, global step 14400: 'val/CER' was not in top 1
# [epoch 30] val loss=0.7222  val/CER=19.4063
# [epoch 30] train loss=0.2047  train/CER=10.6215
# Epoch 30, global step 14880: 'val/CER' was not in top 1
# [epoch 31] val loss=0.7228  val/CER=18.6088
# [epoch 31] train loss=0.1988  train/CER=9.9240
# Epoch 31, global step 15360: 'val/CER' reached 17.65618 (best 17.65618), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=31-step=15360.ckpt' as top 1
# [epoch 32] val loss=0.7191  val/CER=17.6562
# [epoch 32] train loss=0.2531  train/CER=8.4313
# Epoch 32, global step 15840: 'val/CER' reached 17.23527 (best 17.23527), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=32-step=15840.ckpt' as top 1
# [epoch 33] val loss=0.7084  val/CER=17.2353
# [epoch 33] train loss=0.2463  train/CER=7.6902
# Epoch 33, global step 16320: 'val/CER' was not in top 1
# [epoch 34] val loss=0.7023  val/CER=17.7005
# [epoch 34] train loss=0.6060  train/CER=6.9316
# Epoch 34, global step 16800: 'val/CER' was not in top 1
# [epoch 35] val loss=0.7272  val/CER=17.7226
# [epoch 35] train loss=0.2271  train/CER=6.2895
# Epoch 35, global step 17280: 'val/CER' reached 16.94728 (best 16.94728), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=35-step=17280.ckpt' as top 1
# [epoch 36] val loss=0.7118  val/CER=16.9473
# [epoch 36] train loss=0.1013  train/CER=5.7021
# Epoch 36, global step 17760: 'val/CER' reached 16.61497 (best 16.61497), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=36-step=17760.ckpt' as top 1
# [epoch 37] val loss=0.7259  val/CER=16.6150
# [epoch 37] train loss=0.2905  train/CER=5.4323
# Epoch 37, global step 18240: 'val/CER' reached 16.59282 (best 16.59282), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=37-step=18240.ckpt' as top 1
# [epoch 38] val loss=0.7062  val/CER=16.5928
# [epoch 38] train loss=0.1391  train/CER=5.0338
# Epoch 38, global step 18720: 'val/CER' reached 16.41560 (best 16.41560), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=38-step=18720.ckpt' as top 1
# [epoch 39] val loss=0.7251  val/CER=16.4156
# [epoch 39] train loss=0.3777  train/CER=5.0002
# Epoch 39, global step 19200: 'val/CER' reached 16.30483 (best 16.30483), saving model to 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=39-step=19200.ckpt' as top 1
# `Trainer.fit` stopped: `max_epochs=40` reached.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [epoch 40] val loss=0.7251  val/CER=n/a
# ┌───────────────────────────┬───────────────────────────┐
# │      Validate metric      │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │          val/CER          │    16.304828643798828     │
# │          val/DER          │    1.8387240171432495     │
# │          val/IER          │     4.076207160949707     │
# │          val/SER          │    10.389898300170898     │
# │         val/loss          │    0.7250521183013916     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ┌───────────────────────────┬───────────────────────────┐
# │        Test metric        │       DataLoader 0        │
# ├───────────────────────────┼───────────────────────────┤
# │         test/CER          │     18.97557830810547     │
# │         test/DER          │    1.9018802642822266     │
# │         test/IER          │     4.452128887176514     │
# │         test/SER          │     12.62156867980957     │
# │         test/loss         │    0.7528272867202759     │
# └───────────────────────────┴───────────────────────────┘
# {'val_metrics': [{'val/loss': 0.7250521183013916,
#                   'val/CER': 16.304828643798828,
#                   'val/IER': 4.076207160949707,
#                   'val/DER': 1.8387240171432495,
#                   'val/SER': 10.389898300170898}],
#  'test_metrics': [{'test/loss': 0.7528272867202759,
#                    'test/CER': 18.97557830810547,
#                    'test/IER': 4.452128887176514,
#                    'test/DER': 1.9018802642822266,
#                    'test/SER': 12.62156867980957}],
#  'best_checkpoint': 'c:\\Users\\15855\\Desktop\\emg2qwerty\\logs\\2026-03-10\\02-12-31/checkpoints\\epoch=39-step=19200.ckpt'}
#
# ========== Character error breakdown (best ckpt; train is best-val-epoch train) ==========
#   train = n/a (best-val-epoch snapshot not available)
#   train: n/a
#   val: CER=16.3048  IER=4.07621  DER=1.83872  SER=10.3899
#   test: CER=18.9756  IER=4.45213  DER=1.90188  SER=12.6216
# ================================================================================

# %%
# --- 6) Plot train/val CER across epochs ---
# Preferred source: TensorBoard scalar events (if available)
# Fallback: parse the streamed training log in logs/notebook_runs/train_*.log (always available)

from __future__ import annotations

from pathlib import Path
import re
import numpy as np
import matplotlib.pyplot as plt


def _pick_latest(paths: list[Path]) -> Path:
    if not paths:
        raise FileNotFoundError("No matching files found")
    return max(paths, key=lambda p: p.stat().st_mtime)


def _latest_event_file(logs_root: Path) -> Path | None:
    evs = sorted(logs_root.rglob("events.out.tfevents.*"), key=lambda p: p.stat().st_mtime)
    return evs[-1] if evs else None


def _try_load_tb_scalars(event_file: Path, preferred: list[str]) -> dict[str, tuple[np.ndarray, np.ndarray]]:
    try:
        from tensorboard.backend.event_processing import event_accumulator
    except Exception:
        return {}

    ea = event_accumulator.EventAccumulator(str(event_file), size_guidance={"scalars": 0})
    ea.Reload()
    available = ea.Tags().get("scalars", [])
    out: dict[str, tuple[np.ndarray, np.ndarray]] = {}

    # Some Lightning versions write *_epoch. Prefer the plain names but auto-fallback.
    def resolve(tag: str) -> str | None:
        if tag in available:
            return tag
        alt = f"{tag}_epoch"
        if alt in available:
            return alt
        return None

    for tag in preferred:
        rt = resolve(tag)
        if rt is None:
            continue
        scalars = ea.Scalars(rt)
        steps = np.array([s.step for s in scalars], dtype=np.int64)
        values = np.array([s.value for s in scalars], dtype=np.float64)
        out[tag] = (steps, values)

    return out


def _latest_notebook_run_log(repo_root: Path) -> Path:
    nb_dir = repo_root / "logs" / "notebook_runs"
    logs = list(nb_dir.glob("train_*.log"))
    return _pick_latest(logs)


def _parse_log_train_val_cer(log_path: Path) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    # Train: lines like: [epoch 38] train loss=...  train/CER=5.0874
    re_train = re.compile(r"^\[epoch\s+(\d+)\].*?train/CER=([0-9.]+)")
    # Val (preferred): lines like: [epoch 38] val loss=...  val/CER=17.7005
    re_val_epoch = re.compile(r"^\[epoch\s+(\d+)\].*?val/CER=([0-9.]+)")
    # Val (fallback): only when best improves (older logs)
    re_val_best = re.compile(r"^Epoch\s+(\d+),.*?val/CER.*?reached\s+([0-9.]+)")

    train: dict[int, float] = {}
    val: dict[int, float] = {}

    for line in log_path.read_text(encoding="utf-8", errors="ignore").splitlines():
        m = re_train.match(line)
        if m:
            ep = int(m.group(1))
            train[ep] = float(m.group(2))
            continue
        m = re_val_epoch.match(line)
        if m:
            ep = int(m.group(1))
            val[ep] = float(m.group(2))
            continue
        m = re_val_best.match(line)
        if m and int(m.group(1)) not in val:
            ep = int(m.group(1))
            val[ep] = float(m.group(2))
            continue

    if not train and not val:
        raise ValueError(f"Could not parse train/val CER from log: {log_path}")

    # Use union of epochs and align; display as 1-based epochs
    eps = sorted(set(train.keys()) | set(val.keys()))
    x = np.array([e + 1 for e in eps], dtype=np.int64)
    train_y = np.array([train.get(e, np.nan) for e in eps], dtype=np.float64)
    val_y = np.array([val.get(e, np.nan) for e in eps], dtype=np.float64)
    return x, train_y, val_y


logs_root = REPO_ROOT / "logs"

event_file = _latest_event_file(logs_root)
scalars: dict[str, tuple[np.ndarray, np.ndarray]] = {}
if event_file is not None:
    scalars = _try_load_tb_scalars(event_file, ["train/CER", "val/CER"])

if scalars.get("train/CER") is not None or scalars.get("val/CER") is not None:
    print("Using TensorBoard event:", event_file)
    x_train, y_train = scalars.get("train/CER", (np.array([], dtype=np.int64), np.array([], dtype=np.float64)))
    x_val, y_val = scalars.get("val/CER", (np.array([], dtype=np.int64), np.array([], dtype=np.float64)))

    # If steps look like 0..N-1, show as epoch index + 1
    def _epochify(x: np.ndarray) -> np.ndarray:
        if x.size == 0:
            return x
        if x.min() == 0 and np.all(np.diff(x) >= 0) and x.max() < 10_000:
            return x + 1
        return x

    x_train = _epochify(x_train)
    x_val = _epochify(x_val)

    plt.figure(figsize=(8, 4))
    if y_train.size:
        plt.plot(x_train, y_train, label="train/CER")
    if y_val.size:
        plt.plot(x_val, y_val, label="val/CER")
    plt.title("CER vs epoch")
    plt.xlabel("epoch")
    plt.ylabel("CER")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()
else:
    # Fallback: parse the streamed notebook log (this is what you see printed during training)
    log_path = _latest_notebook_run_log(REPO_ROOT)
    print("TensorBoard scalars not found; falling back to log parse.")
    print("Using log:", log_path)

    x, train_y, val_y = _parse_log_train_val_cer(log_path)

    # --- Plot 1: full curve (all epochs) ---
    plt.figure(figsize=(8, 4))
    plt.plot(x, train_y, label="train/CER")
    plt.plot(x, val_y, label="val/CER")
    plt.title("CER vs epoch (full)")
    plt.xlabel("epoch")
    plt.ylabel("CER")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- Plot 2: zoomed curve (skip early exploding CER) ---
    # Heuristic: find the first epoch where BOTH train+val are <= threshold,
    # then plot from there. This keeps late-epoch changes visible.
    threshold = 150.0
    ok = np.isfinite(train_y) & np.isfinite(val_y) & (train_y <= threshold) & (val_y <= threshold)
    start_idx = int(np.argmax(ok)) if np.any(ok) else 0

    x2 = x[start_idx:]
    train2 = train_y[start_idx:]
    val2 = val_y[start_idx:]

    plt.figure(figsize=(8, 4))
    plt.plot(x2, train2, label="train/CER")
    plt.plot(x2, val2, label="val/CER")
    plt.title(f"CER vs epoch (zoom; start at epoch {int(x2[0])} with CER<= {threshold:g})" if x2.size else "CER vs epoch (zoom)")
    plt.xlabel("epoch")
    plt.ylabel("CER")
    plt.grid(True, alpha=0.3)
    plt.legend()

    # Set a tighter y-limit based on the zoomed segment
    all2 = np.concatenate([train2[np.isfinite(train2)], val2[np.isfinite(val2)]])
    if all2.size:
        hi2 = float(np.nanpercentile(all2, 95))
        plt.ylim(0, max(10.0, hi2 * 1.15))

    plt.tight_layout()
    plt.show()
# Out:
# TensorBoard scalars not found; falling back to log parse.
# Using log: c:\Users\15855\Desktop\emg2qwerty\logs\notebook_runs\train_2026-03-10_02-12-28.log
